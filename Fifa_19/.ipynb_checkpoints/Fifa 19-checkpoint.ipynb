# %% [markdown]
# ## Fifa 19
#
# Dataset: https://www.kaggle.com/karangadiya/fifa19
#
# Taking a closer look into:
#
# - Countries
# - Clubs
# - Players

# %%
import numpy as np 
import pandas as pd 
import re
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set(style="whitegrid")

# %% [markdown]
# ### I. Loading the data

# %%
data = pd.read_csv('./data.csv', index_col = 'Unnamed: 0')

# %%
data.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %% [markdown]
# **Key columns:**
#
# ID: unique id for every player
#
# Name: name
#
# Age: age
#
# Nationality: nationality
#
# Overall: overall rating
#
# Potential: potential rating
#
# Club: current club
#
# Value: current market value
#
# Wage: current wage
#
# Position: position on the pitch

# %% [markdown]
# ### II. Converting numeric columns

# %%
data['Wage'].head()
# Out:
# 0    €565K
# 1    €405K
# 2    €290K
# 3    €260K
# 4    €355K
# Name: Wage, dtype: object

# %%
data['Value'].head()
# Out:
# 0    €110.5M
# 1       €77M
# 2    €118.5M
# 3       €72M
# 4      €102M
# Name: Value, dtype: object

# %%
data['Wage'] = data['Wage'].apply(lambda x: int(re.findall('\d+', x)[0] + '000'))
data['Value'] = data['Value'].apply(lambda x: 'M' in x and int((re.findall('\d+\.*\d*', x)[0] + '000000').replace('.', '')) or int((re.findall('\d+\.*\d*', x)[0] + '000').replace('.', '')))

# %%
data['Wage'].head()
# Out:
# 0    565000
# 1    405000
# 2    290000
# 3    260000
# 4    355000
# Name: Wage, dtype: int64

# %%
data['Value'].head()
# Out:
# 0    1105000000
# 1      77000000
# 2    1185000000
# 3      72000000
# 4     102000000
# Name: Value, dtype: int64

# %% [markdown]
# ### III. Country
#
# - Comparing top 10 countries in terms of overall score and potential score.
# - Which country is most likely to win the next world cup?

# %%
data.groupby('Nationality')['Overall'].median().sort_values(ascending=False)
# Out:
# Nationality
# United Arab Emirates    77.0
# Oman                    72.0
# Dominican Republic      72.0
# São Tomé & Príncipe     72.0
# Israel                  71.5
# Mozambique              71.5
# Togo                    71.0
# Portugal                71.0
# New Caledonia           71.0
# Cape Verde              71.0
# Russia                  71.0
# Brazil                  71.0
# Fiji                    71.0
# Ukraine                 71.0
# Libya                   70.5
# Algeria                 70.5
# Kuwait                  70.0
# Serbia                  70.0
# Morocco                 70.0
# DR Congo                70.0
# Czech Republic          70.0
# Croatia                 70.0
# Paraguay                70.0
# Peru                    70.0
# Chad                    70.0
# Romania                 70.0
# Zimbabwe                70.0
# Central African Rep.    70.0
# Uruguay                 70.0
# Trinidad & Tobago       70.0
#                         ...
# ...

# %%
top_ten_countries = data['Nationality'].value_counts().head(10).index.values
top_ten_countries_df = data.loc[data['Nationality'].isin(top_ten_countries), :]

# %%
# visualising it against overall score
sns.set(style="whitegrid")
plt.figure(figsize=(10, 8))
p = sns.boxplot(x = 'Nationality', y = 'Overall', data = top_ten_countries_df, palette = "coolwarm")

# %%
# visualising it against potential score
sns.set(style="whitegrid")
plt.figure(figsize=(10, 8))
p = sns.boxplot(x = 'Nationality', y = 'Potential', data = top_ten_countries_df, palette = "coolwarm")

# %% [markdown]
# We can see that in terms of overall score, Brazil, Spain and Argentina have the higher median score. This tells us that these countries have better players, which leads us to be hopeful that they may win the next world cup. We can also see that these 3 countries' median scores are also high in terms of potential score, which means that their players could potentially get even better, leading to their increased chances of winning the next world cup.

# %% [markdown]
# ### IV. Leagues
#
# - Comparing the clubs in the 5 major leagues
# - Visualizing the clubs in the Champions League

# %%
Laliga_Santander = ['Athletic Club','Atlético Madrid','CD Leganés','D. Alavés','FC Barcelona','Getafe CF','Girona FC','Levante UD','R. Valladolid CF','Rayo Vallecno','RC Celta','RCD Espanyol','Real Betis','Real Madrid','Real Sociedad','SD Eibar','SD Huesca','Sevilla FC','Valencia CF','Villarreal CF']

# %%
Serie_A_Tim = ['Atalanta','Bologna','Cagliari','Chievo Verona','Empoli','Fiorentina','Frosinone','Genoa','Inter','Juventus','Lazio','Milan','Napoli','Parma','Roma','Sampdoria','Sassuolo','SPAL','Torino','Udinese']

# %%
Premier_League = ['Arsenal','Bournemouth','Brighton','Burnley','Cardiff City','Chelsea','Crystal Palace','Everton','Fulham','Huddersfield','Leicester City','Liverpool','Manchester City','Manchester United','Newcastle Utd','Southampton','Spurs','Watford','West Ham','Wolves']

# %%
Ligue_1_Conforama = ['Amiens SC','Angers SCO','AS Monaco','ASSE','Dijon FCO','EA Guingamp','FC Nantes','Girondins de Bx','LOSC Lille','Montpellier HSC','Nîmes Olympique','OGC Nice','OL','OM','Paris','RC Strasbourg','SM Caen','Stade de Reims','Stade Rennais','Toulouse FC']

# %%
Bundesliga = ['1. FC Nürnberg','1. FSV Mainz 05','Dortmund','Düsseldorf','FC Augsburg','FC Bayern','Frankfurt','Hannover 96','Hertha BSC','Leverkusen','M\'gladbach','RB Leipzig','SC Freiburg','Schalke','TSG Hoffenheim','VfB Stuttgart','VfL Wolfsburg','Werder Bremen']

# %%
# mapping the clubs that are in the top 5 leagues
for i, row in data.iterrows(): 
    if row['Club'] in Laliga_Santander:
        data.at[i,'Top 5 leagues'] = 'Laliga Santander'
    elif row['Club'] in Serie_A_Tim:
        data.at[i,'Top 5 leagues'] = 'Serie A Tim'
    elif row['Club'] in Premier_League:
        data.at[i,'Top 5 leagues'] = 'Premier League'
    elif row['Club'] in Ligue_1_Conforama:
        data.at[i,'Top 5 leagues'] = 'Ligue 1 Conforama'
    elif row['Club'] in Bundesliga:
        data.at[i,'Top 5 leagues'] = 'Bundesliga'

# %%
data.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
data.groupby('Top 5 leagues')['Overall'].median()
# Out:
# Top 5 leagues
# Bundesliga           73
# Laliga Santander     75
# Ligue 1 Conforama    71
# Premier League       75
# Serie A Tim          74
# Name: Overall, dtype: int64

# %%
# about the same. so next to look at distribution
plt.figure(figsize=(10,8))
p = sns.boxplot(x = 'Top 5 leagues', y = 'Overall', data = data, palette = "coolwarm")

# %%
data.groupby('Top 5 leagues')['Potential'].median()
# Out:
# Top 5 leagues
# Bundesliga           77
# Laliga Santander     79
# Ligue 1 Conforama    76
# Premier League       79
# Serie A Tim          78
# Name: Potential, dtype: int64

# %%
# about the same. so next to look at distribution
plt.figure(figsize=(10,8))
p = sns.boxplot(x = 'Top 5 leagues', y = 'Potential', data = data, palette = "coolwarm")

# %%
# champions league 
champions_league = [
    'Real Madrid', 
    'Atlético Madrid', 
    'Bayern München', 
    'Barcelona', 
    'Juventus', 
    'Paris', 
    'Manchester City', 
    'Lokomotiv Moskva', 
    'Borussia Dortmund',
    'Porto',
    'Manchester United',
    'Shakhtar Donetsk',
    'Benfica',
    'Napoli',
    'Tottenham Hotspur',
    'Roma',
    'Liverpool',
    'Schalke',
    'Lyon',
    'Monaco',
    'Ajax',
    'CSKA Moskva',
    'PSV Eindhoven',
    'Valencia',
    'Viktoria Plzeň',
    'Club Brugge',
    'Galatasaray',
    'Young Boys',
    'Internazionale Milano',
    'Hoffenheim',
    'Crvena zvezda',
    'AEK Athens'
]

# %%
# mapping the clubs that are in the top 5 leagues
for i, row in data.iterrows(): 
    if row['Club'] in champions_league:
        data.at[i,'Champions league'] = 'Champions league'

# %%
data.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
data.groupby('Champions league')['Overall'].median()
# Out:
# Champions league
# Champions league    77
# Name: Overall, dtype: int64

# %%
data.groupby('Champions league')['Potential'].median()
# Out:
# Champions league
# Champions league    81
# Name: Potential, dtype: int64

# %%
plt.figure(figsize=(10,8))
p = sns.boxplot(x = 'Champions league', y = 'Overall', data = data, palette = "coolwarm")

# %% [markdown]
# We can see that the median for Champions League is higher than the top 5 leagues individually. This is consistent with expecations as only the top clubs from the leagues progress to the Champions Leagues.

# %% [markdown]
# ### V. Clubs
#
# - Wages of players across clubs
# - Market value of players across clubs

# %%
# getting top ten clubs
top_ten_clubs = ['FC Barcelona', 'Real Madrid', 'Manchester City', 'Arsenal', 'Liverpool', 'Manchester United', 'Borussia Dortmund', 'FC Bayern München', 'Juventus', 'Paris Saint-Germain']
top_ten_clubs_df = data.loc[data['Club'].isin(top_ten_clubs), :]

# %%
# plotting against players' wages
sns.set(style="whitegrid")
plt.figure(figsize=(10,8))
p = sns.boxplot(x = 'Club', y = 'Wage', data = top_ten_clubs_df, palette = "coolwarm")
p = plt.xticks(rotation=45)

# %%
# plotting against market value
sns.set(style="whitegrid")
plt.figure(figsize=(10,8))
p = sns.boxplot(x = 'Club', y = 'Value', data = top_ten_clubs_df, palette = "coolwarm")
p = plt.xticks(rotation=45)

# %% [markdown]
# ### VI. Players
#
# - Value by age
# - Value by position
# - Wage by age
# - Wage by position

# %%
plt.figure(figsize=(10,8))
p = sns.lineplot(x = 'Age', y = 'Overall', ci = None, data = data, label = 'Overall')
p = sns.lineplot(x = 'Age', y = 'Potential', ci = None, data = data, label = 'Potential')
p = plt.ylabel('Potential vs Overall')
p = plt.legend(loc = 1)

# %% [markdown]
# We can see that players usually hit their potential around 30 years old.

# %%
mean_value_per_age = data.groupby('Age')['Value'].mean()
plt.figure(figsize=(10,8))
p = sns.barplot(x = mean_value_per_age.index, y = mean_value_per_age.values, palette = "coolwarm")
p = plt.xticks(rotation=90)

# %% [markdown]
# We can see that players' are valued at the highest between ages 23 - 31, and peaking at age 26.

# %%
mean_wage_per_age = data.groupby('Age')['Wage'].mean()
plt.figure(figsize=(10,8))
p = sns.barplot(x = mean_wage_per_age.index, y = mean_wage_per_age.values, palette = "coolwarm")
p = plt.xticks(rotation=90)

# %% [markdown]
# We are see that the players' wages are relatively steady between 26-33, peaking at age 31, and on a decline after age 33.

# %%
avg_value_by_position = data.groupby('Position')['Value'].mean()
plt.figure(figsize=(10,8))
p = sns.boxplot(x = 'Position', y = 'Value', data = data, palette = "coolwarm")
p = plt.xticks(rotation=90)
p = plt.ylim(0, 200000000)

# %% [markdown]
# Most valued positions in terms of market value are LF and RF.
# We can see that the order follows forwards > midfielders > defenders > goalkeepers.

# %%
avg_wage_by_position = data.groupby('Position')['Wage'].mean()
plt.figure(figsize=(10,8))
p = sns.boxplot(x = 'Position', y = 'Wage', data = data, palette = "coolwarm")
p = plt.xticks(rotation=90)
p = plt.ylim(0, 600000)

# %% [markdown]
# We can see that the trend of the wages is related to their market value as we see the same order of decreasing wages as compared to their market value.
